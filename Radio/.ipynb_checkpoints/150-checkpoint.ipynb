# %%
import json

# %%
with open(r'E:\_Files\btn\data_outdoor_more\第2个数据.json','rb') as user_file:
    file_contents1 = user_file.read()

# %%
parsed_json1 = json.loads(file_contents1)
parsed_json1.keys()
# Out:
# dict_keys(['name', 'freData'])

# %%
data = parsed_json1['freData']
len(data)
# Out:
# 240001

# %%
for k in range(1600):
    dmax=-111111
    for i in range(150*k,150*(k+1)):
        if data[i]>dmax:
            dmax=data[i]
    print(dmax,end=' ')
# Out:
# 294 221 165 246 136 116 107 182 157 133 114 123 132 158 102 265 383 121 431 214 417 457 547 331 38 -2 21 -11 60 -27 -37 -21 -7 -10 72 -70 -43 268 -52 -56 -58 -49 -33 -1 -19 125 11 -17 159 -15 -1 -21 37 -17 48 -65 -18 -42 18 23 11 79 -41 321 -33 -59 -47 -46 -55 -52 -38 -40 -60 17 -35 -49 -69 -18 -39 -36 182 -28 -46 -51 -8 -39 -63 -26 -43 -59 412 120 224 -19 -49 -14 -46 -61 8 -45 39 -56 60 1 -52 -44 -57 16 -68 -2 -4 140 -55 104 11 -67 -59 -54 -73 -86 -42 -83 -29 0 -8 -58 28 37 15 -82 -75 -78 -78 -89 -72 -35 -72 -65 5 -80 -89 3 -82 -85 -37 -80 -64 -80 -30 -62 -58 -80 -5 100 -67 -79 -79 -67 -69 -56 -64 -71 -61 -70 -38 -14 -9 -49 -63 -72 -64 -55 -55 -66 -76 -84 -89 -76 -55 -57 -73 -52 -70 -73 -71 -84 -76 -85 -64 -67 -69 -64 38 -75 -58 -64 143 199 184 204 210 189 221 250 235 129 -75 -80 -81 -73 -71 -75 -71 -34 -82 -72 -65 -62 -75 -72 -78 -52 -62 -54 312 304 186 263 219 252 -59 -70 -36 -72 -54 -70 -74 38 -57 -77 -75 -74 139 225 244 214 218 362 182 176 173 -80 -66 -64 -63 -61 -53 -75 -78 -76
# ...

# %%
k=2
dmax=-111111
for i in range(150*k,150*(k+1)):
    if data[i]>dmax:
        dmax=data[i]
print(dmax)
# Out:
# 165
