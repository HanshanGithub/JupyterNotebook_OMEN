# %%
imageMatrix = data - np.mean(data, axis=0)

# %%
count = len(data)
# count

# %%
def pca(data):
    """

    :param data: 待降维的原始数据
    :param k: 保留的特征数，即降低到的维数
    :return: 降维后还原得到的数据
    """
    print("原始数据行状：", data.shape)

    # 1. 均值归一化
    X_demean = data - np.mean(data, axis=0)  # 按行操作，取每一列的均值

    # 2. 计算数据的协方差矩阵
    # np.dot(np.ones([97, 2]), np.ones([2, 1]))
    C = np.dot(X_demean.T, X_demean) / len(X_demean)
    # C = X_demean.T * X_demean / len(X_demean)
    # print("协方差矩阵：", C)

    # 3. 计算特征值，特征向量
    # 奇异值分解
    U, S, V = np.linalg.svd(C)
    # print("特征值：", S)
    # print("特征向量：", U)

    # 4. 实现降维
    U1 = U[:, :20]  # 降到100维，那么取特征向量的前100列
    X_reduction = np.dot(X_demean , U1)
    print("降维后的数据形状：", X_reduction.shape)  # 仅保留100个特征

    # 5. 数据还原
    # x做过均值归一化，因此还需要加上各个维度的均值。
    X_restore = np.dot(X_reduction , U1.T) + np.mean(data, axis=0)
    return X_restore, X_reduction

# %%
def draw(data):
    data = data.reshape(4000,48,48)
    fig, ax = plt.subplots(2, 5, figsize=(8, 3))
    centers = data[100:110]
    for axi, center in zip(ax.flat, centers):
        axi.set(xticks=[], yticks=[])
        axi.imshow(center, interpolation='nearest', cmap='gray') # , cmap='gray'

# %%
def load_ndarray():
    data = np.load(r'E:/_files/ndPic.npy')
    data = data.astype(np.uint8)
#     data = data.reshape(4000,48,48)
    return data

# %%
import numpy as np
from scipy.io import loadmat
import matplotlib.pyplot as plt

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ## testing

# %%
mylabel = np.load(r'E:/_files/label.npy')
# label = data.astype(np.uint8)

# %%
label.shape
label[100:110]
# Out:
# array([3, 2, 6, 3, 4, 3, 2, 0, 2, 3], dtype=int64)

# %%
accNum = 0
for i in range(len(label)):
    if(label[i]==label_predict[i]):
        accNum += 1
print('acc: %.2f'%(accNum/len(label)*100),'%')
# Out:
# acc: 14.47 %

# %%
label[100:110]
# type(label)
# len(label)
# Out:
# array([3, 2, 6, 3, 4, 3, 2, 0, 2, 3], dtype=int64)

# %%
label_predict[100:110]
# Out:
# array([4, 2, 2, 0, 4, 6, 3, 5, 4, 5])

# %%
label_predict = clusters.labels_

# %% [markdown]
# # end

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(mylabel,labels)
# Out:
# 0.25825

# %%
for i in range(7):
    mask = (clusters == i)
    labels[mask] = mode(mylabel[mask])[0]
# Out:
# C:\Users\16340\AppData\Local\Temp\ipykernel_16364\3044886178.py:3: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   labels[mask] = mode(mylabel[mask])[0]

# %%
labels = np.zeros_like(clusters)

# %%
from scipy.stats import mode

# %%
fig, ax = plt.subplots(2, 5, figsize=(8, 3))
for axi, center in zip(ax.flat, centers):
    axi.set(xticks=[], yticks=[])
    axi.imshow(center, interpolation='nearest', cmap=plt.cm.binary)

# %%
centers = kmeans.cluster_centers_.reshape(7,48,48)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [139], in <cell line: 1>()
# ----> 1 centers = kmeans.cluster_centers_.reshape(7,48,48)
#
# ValueError: cannot reshape array of size 140 into shape (7,48,48)

# %%
kmeans.cluster_centers_.shape
# Out:
# (7, 20)

# %%
clusters = kmeans.fit_predict(tem)

# %%
kmeans = KMeans(n_clusters=7, random_state=0)

# %%
draw(restore)

# %%
tem.shape
# Out:
# (4000, 20)

# %%
restore , tem= pca(data)
# Out:
# 原始数据行状： (4000, 2304)
# 降维后的数据形状： (4000, 20)

# %%
draw(data)

# %%
len(data)
data.shape
# Out:
# (4000, 2304)

# %%
data[:10].shape
# Out:
# (10, 2304)

# %%
data = load_ndarray()
